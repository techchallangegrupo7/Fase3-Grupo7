# %%
## montar o google driver
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
DATA_DIR = "/content/drive/MyDrive/FIAP/tcFase3Grupo9"

# %%
# !pip uninstall -y torch
# !pip install torch --index-url https://download.pytorch.org/whl/cu118  # ou cu121 se sua GPU suportar

# !pip uninstall -y torch torchvision
# !pip install torch torchvision --index-url https://download.pytorch.org/whl/cu118
# Out:
# Found existing installation: torch 2.6.0+cu124
# Uninstalling torch-2.6.0+cu124:
#   Successfully uninstalled torch-2.6.0+cu124
# Looking in indexes: https://download.pytorch.org/whl/cu118
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 23.2/23.2 MB 79.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 875.6/875.6 kB 30.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.1/13.1 MB 128.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 663.9/663.9 MB 2.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 417.9/417.9 MB 3.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 168.4/168.4 MB 5.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.1/58.1 MB 14.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 128.2/128.2 MB 7.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 204.1/204.1 MB 5.7 MB/s eta 0:00:00
# ...

# %%
# !pip uninstall -y torchvision
# !pip install torchvision --index-url https://download.pytorch.org/whl/cu118
# Out:
# Found existing installation: torchvision 0.22.0+cu118
# Uninstalling torchvision-0.22.0+cu118:
#   Successfully uninstalled torchvision-0.22.0+cu118
# Looking in indexes: https://download.pytorch.org/whl/cu118
# ...
#   Using cached https://download.pytorch.org/whl/cu118/torchvision-0.22.0%2Bcu118-cp311-cp311-manylinux_2_28_x86_64.whl.metadata (6.1 kB)
# ...
# Using cached https://download.pytorch.org/whl/cu118/torchvision-0.22.0%2Bcu118-cp311-cp311-manylinux_2_28_x86_64.whl (6.7 MB)
# ...
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# fastai 2.7.19 requires torch<2.7,>=1.10, but you have torch 2.7.0+cu118 which is incompatible.
# ...

# %%
# !pip install bitsandbytes
# !pip install -U bitsandbytes
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 76.1/76.1 MB 9.1 MB/s eta 0:00:00
# ...

# %%
def format_prompt(instruction, input_text):
    return f"""### Instruction:
{instruction}

### Input:
{input_text}

### Response:
"""

# %%
from transformers import AutoModelForCausalLM, AutoTokenizer
from peft import PeftModel
import torch

# %%
import torch
print(torch.cuda.is_available())  # deve retornar True
# Out:
# True

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

base_model_name = "unsloth/Meta-Llama-3.1-8B-bnb-4bit"  # substitua pelo seu modelo base
lora_dir = f"{DATA_DIR}/lora_model_alpaca"
lora_dir_2_epochs = f"{DATA_DIR}/lora_model_alpaca-2epochs"

# Carregar tokenizer e modelo base
tokenizer = AutoTokenizer.from_pretrained(base_model_name)
base_model = AutoModelForCausalLM.from_pretrained(base_model_name, device_map="auto", torch_dtype=torch.float16)
# base_model.to(device)
base_model.eval()

# Carregar modelo com LoRA aplicado
tokenizer_lora_dir = AutoTokenizer.from_pretrained(lora_dir)
lora_model = PeftModel.from_pretrained(base_model, lora_dir)
# lora_model.to(device)
lora_model.eval()

# Carregar modelo com LoRA aplicado
tokenizer_lora_dir_2_epochs = AutoTokenizer.from_pretrained(lora_dir_2_epochs)
lora_model_2_epochs = PeftModel.from_pretrained(base_model, lora_dir_2_epochs)
# lora_model.to(device)
lora_model_2_epochs.eval()
# Out:
# /usr/local/lib/python3.11/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# tokenizer_config.json:   0%|          | 0.00/50.6k [00:00<?, ?B/s]
# Xet Storage is enabled for this repo, but the 'hf_xet' package is not installed. Falling back to regular HTTP download. For better performance, install the package with: `pip install huggingface_hub[hf_xet]` or `pip install hf_xet`
# ...

# %%
def gerar_resposta_base(instruction, input_text, max_length=512):
    prompt = format_prompt(instruction, input_text)
    inputs = tokenizer(prompt, return_tensors="pt").to(device)
    with torch.no_grad():
        outputs = base_model.generate(
            **inputs,
            max_length=max_length,
            do_sample=True,
            top_p=0.9,
            temperature=0.7,
            eos_token_id=tokenizer.eos_token_id,
        )
    return tokenizer.decode(outputs[0], skip_special_tokens=True)


def gerar_resposta_lora(instruction, input_text, max_length=512):
    prompt = format_prompt(instruction, input_text)
    inputs = tokenizer_lora_dir(prompt, return_tensors="pt").to(device)
    with torch.no_grad():
        outputs = lora_model.generate(
            **inputs,
            max_length=max_length,
            do_sample=True,
            top_p=0.9,
            temperature=0.7,
            eos_token_id=tokenizer_lora_dir.eos_token_id,
        )
    return tokenizer_lora_dir.decode(outputs[0], skip_special_tokens=True)


def gerar_resposta_lora_2_epochs(instruction, input_text, max_length=512):
    prompt = format_prompt(instruction, input_text)
    inputs = tokenizer_lora_dir_2_epochs(prompt, return_tensors="pt").to(device)
    with torch.no_grad():
      outputs = lora_model_2_epochs.generate(
          **inputs,
          max_length=max_length,
          do_sample=False,              # Desativa amostragem aleatória
          eos_token_id=tokenizer_lora_dir_2_epochs.eos_token_id,
      )
    return tokenizer_lora_dir_2_epochs.decode(outputs[0], skip_special_tokens=True)

# %%
instruction = "Imagine you're introducing this product to a customer. Create a product summary from this title."
input_text = "Miss Marple's Final Cases"

print("Resposta modelo base:")
print(gerar_resposta_base(instruction, input_text))

print("\nResposta modelo LoRA:")
print(gerar_resposta_lora(instruction, input_text))

print("\nResposta modelo LoRA PURO:")
print(gerar_resposta_lora_2_epochs(instruction, input_text))
# Out:
# Resposta modelo base:
# ### Instruction:
# Imagine you're introducing this product to a customer. Create a product summary from this title.
#
# ### Input:
# Miss Marple's Final Cases
#
# ### Response:
# The title is misleading. The 12 stories in this collection have been pulled from the 20 volumes of Miss Marple's adventures. The book is a good sampler for the newcomer, but the old hands will be disappointed. The best story here is "The Blue Geranium," in which Miss Marple's cousin is murdered. The others are a mixed bag. "The Affair at the Bungalow" is a pretty good whodunit, but the rest are either too thin or too slight to be considered in the same class with the best of Christie. Miss Marple is the only character who carries the book along. The rest are too sketchy to be memorable. The book is a good sampler for the newcomer, but the old hands will be disappointed.Copyright 1989 Reed Business Information, Inc.
#
# Resposta modelo LoRA:
# ### Instruction:
# ...

# %% [markdown]
# ##Conclusão baseada na análise:

# %% [markdown]
# Legal! Dá para perceber claramente que o modelo LoRA treinado está gerando respostas mais focadas e alinhadas com o estilo sintético do seu dataset, enquanto o modelo base dá uma resposta mais longa, mais “genérica” e menos direta, provavelmente porque ele “conhece” textos mais variados e não foi adaptado.
#
# O que isso mostra?
#
# O fine-tuning com LoRA surtiu efeito ao especializar o modelo para a tarefa e estilo dos seus dados.
#
# A resposta do LoRA tende a ser mais concisa, direta e com um tom comercial, que é o que seu dataset instrui.
#
# O modelo base ainda tem mais “conhecimento geral” e produz respostas mais detalhadas, mas menos ajustadas ao seu caso.
